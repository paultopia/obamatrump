# %%
import requests
obamasample = requests.get("https://obamawhitehouse.archives.gov/the-press-office/remarks-president-welcoming-senior-staff-and-cabinet-secretaries-white-house")

# %%
obamasample.text
# Out:
# '<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->\n<!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->\n<!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->\n<!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html  lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video#"><!--<![endif]-->\n\n<head>\n  <!--[if IE]><![endif]-->\n<!--[if IE]><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<![endif]--><meta charset="utf-8" />\n<link rel="dns-prefetch" href="//obamawhitehouse.archives.gov" />\n<link rel="dns-prefetch" href="//platform.twitter.com" />\n<link rel="apple-touch-icon" sizes="152x152" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/iOS_152x152.png" />\n<link rel="apple-touch-icon" sizes="167x167" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/iOS_167x167.png" />\n<link rel="apple-touch-icon" sizes="120x120" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/iOS_120x120.png" />\n<link rel="apple-touch-icon" sizes="76x76" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/iOS_76x76.png" />\n<link rel="apple-touch-icon" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/iOS_76x76.png" />\n<link rel="apple-touch-icon" sizes="180x180" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/iOS_180x180.png" />\n<link rel="apple-touch-icon-precomposed" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/apple-touch-icon-60x60-precomposed.png" />\n<link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/apple-touch-icon-76x76-precomposed.png" />\n<link rel="apple-touch-icon-precomposed" sizes="114x114" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/apple-touch-icon-114x114-precomposed.png" />\n<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/apple-touch-icon-72x72-precomposed.png" />\n<link rel="apple-touch-icon-precomposed" sizes="60x60" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/apple-touch-icon-60x60-precomposed.png" />\n<link rel="apple-touch-icon-precomposed" sizes="57x57" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/apple-touch-icon-57x57-precomposed.png" />\n<link rel="icon" type="image/png" sizes="16x16" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/favicon-16x16.png" />\n<link rel="icon" type="image/png" sizes="32x32" href="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/favicon-32x32.png" />\n<meta name="msapplication-square150x150logo" content="https://obamawhitehouse.archives.gov/profiles/forall/themes/custom/fortyfour/images/fortyfour/favicons/mstile-150x150.png" ...

# %%
from bs4 import BeautifulSoup

# %%
osoup = BeautifulSoup(obamasample.text)
# Out:
# /Users/pauliglot/anaconda/envs/py35/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
odate = osoup.find("meta",  property="article:published_time")

# %%
odate
# Out:
# <meta content="2009-01-21T00:00:00-05:00" property="article:published_time"/>

# %%
odate["content"]
# Out:
# '2009-01-21T00:00:00-05:00'

# %%
from dateutil import parser
od=parser.parse(odate["content"])

# %%
od
# Out:
# datetime.datetime(2009, 1, 21, 0, 0, tzinfo=tzoffset(None, -18000))

# %%
trumpsample=requests.get("https://www.whitehouse.gov/the-press-office/2017/07/21/remarks-president-trump-visit-survivors-uss-arizona")

# %%
tsoup = BeautifulSoup(trumpsample.text)
td = parser.parse(tsoup.find("meta",  property="article:published_time")["content"])
# Out:
# /Users/pauliglot/anaconda/envs/py35/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
td
# Out:
# datetime.datetime(2017, 7, 21, 16, 51, 11, tzinfo=tzoffset(None, -14400))

# %%
td > od
# Out:
# True

# %%
od > td
# Out:
# False

# %% [markdown]
# Ok, so I can compare dates.  Can I construct my own date?

# %%
from datetime import datetime
datetime.strptime("2009-07-21", "%Y-%m-%d")
# Out:
# datetime.datetime(2009, 7, 21, 0, 0)

# %% [markdown]
# So strategy: scrape all the speeches from both obama and trump and dump in a dataset, then compare by date.
